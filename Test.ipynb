# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
from tensorflow.keras import layers, regularizers
import random
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt
import itertools

# %%
rootDir = './animals-dataset'
trainingDir = rootDir + '/training'
testDir = rootDir + '/test'

# %%
seed = 512
validation_split = 0.2
interpolation = "bilinear"
batch_size = 16
img_height = 256
img_width = 256

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    trainingDir,
    validation_split=validation_split,
    subset="training",
    seed=seed,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    interpolation=interpolation
)
# Out:
# Found 837 files belonging to 4 classes.
# Using 670 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    trainingDir,
    validation_split=validation_split,
    subset="validation",
    seed=seed,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    interpolation=interpolation
)
# Out:
# Found 837 files belonging to 4 classes.
# Using 167 files for validation.

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    testDir,
    seed=seed,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    interpolation=interpolation
)
# Out:
# Found 80 files belonging to 4 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['chicken', 'elefant', 'sheep', 'spider']

# %%
plt.figure(figsize=(15, 15))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break

AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# (16, 256, 256, 3)
# (16,)

# %%
num_classes = len(class_names)
print(num_classes)
    
# model = tf.keras.Sequential([
#     layers.experimental.preprocessing.Rescaling(1./255),
#     layers.Conv2D(16, 2, activation='relu'),
#     layers.MaxPooling2D(),
#     layers.Conv2D(16, 2, activation='relu'),
#     layers.MaxPooling2D(),
#     layers.Conv2D(16, 2, activation='relu'),
#     layers.MaxPooling2D(),
#     layers.Flatten(),
#     layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
#     layers.Dropout(0.5),
#     layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
#     layers.Dropout(0.5),
#     layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
#     layers.Dropout(0.5),
#     #layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
#     #layers.Dropout(0.5),
#     #layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
#     #layers.Dropout(0.5),
#     layers.Dense(num_classes)
# ])
    
model = tf.keras.Sequential([
    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    layers.experimental.preprocessing.RandomRotation(factor=0.2),
    layers.Dropout(0.1),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes)
])
# Out:
# 4

# %%
model.compile(
  optimizer=tf.optimizers.Adam(learning_rate=0.001),
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_13 (Rescaling)     (None, 256, 256, 3)       0
# _________________________________________________________________
# random_rotation_6 (RandomRot (None, 256, 256, 3)       0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 128, 128, 32)      4640
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 65536)             0
# _________________________________________________________________
# dense_35 (Dense)             (None, 64)                4194368
# _________________________________________________________________
# dense_36 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_37 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 4,226,788
# Trainable params: 4,226,788
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    train_ds,
    #steps_per_epoch=100,
    validation_data=val_ds,
    epochs=25
)
# Out:
# Epoch 1/25
# 42/42 [==============================] - 9s 218ms/step - loss: 0.7897 - accuracy: 0.7403 - val_loss: 1.0776 - val_accuracy: 0.6048
# Epoch 2/25
# 42/42 [==============================] - 9s 225ms/step - loss: 0.7701 - accuracy: 0.7254 - val_loss: 0.9028 - val_accuracy: 0.7545
# Epoch 3/25
# 42/42 [==============================] - 10s 227ms/step - loss: 0.7107 - accuracy: 0.7731 - val_loss: 0.9040 - val_accuracy: 0.7365
# Epoch 4/25
# 42/42 [==============================] - 9s 215ms/step - loss: 0.6751 - accuracy: 0.7791 - val_loss: 0.8821 - val_accuracy: 0.7305
# Epoch 5/25
# 42/42 [==============================] - 9s 223ms/step - loss: 0.7166 - accuracy: 0.7791 - val_loss: 0.8803 - val_accuracy: 0.7126
# Epoch 6/25
# 42/42 [==============================] - 9s 219ms/step - loss: 0.7103 - accuracy: 0.7552 - val_loss: 0.8556 - val_accuracy: 0.7425
# Epoch 7/25
# 42/42 [==============================] - 9s 222ms/step - loss: 0.7105 - accuracy: 0.7896 - val_loss: 0.8543 - val_accuracy: 0.7425
# Epoch 8/25
# 42/42 [==============================] - 9s 218ms/step - loss: 0.6243 - accuracy: 0.8075 - val_loss: 0.8067 - val_accuracy: 0.7725
# Epoch 9/25
# 42/42 [==============================] - 9s 221ms/step - loss: 0.6226 - accuracy: 0.8224 - val_loss: 0.8920 - val_accuracy: 0.7605
# Epoch 10/25
# 42/42 [==============================] - 9s 218ms/step - loss: 0.6031 - accuracy: 0.8373 - val_loss: 0.8854 - val_accuracy: 0.7485
# Epoch 11/25
# 42/42 [==============================] - 9s 218ms/step - loss: 0.5797 - accuracy: 0.8388 - val_loss: 0.8489 - val_accuracy: 0.7485
# Epoch 12/25
# 42/42 [==============================] - 9s 217ms/step - loss: 0.6630 - accuracy: 0.8209 - val_loss: 0.8960 - val_accuracy: 0.7545
# Epoch 13/25
# 42/42 [==============================] - 9s 218ms/step - loss: 0.6000 - accuracy: 0.8284 - val_loss: 0.7467 - val_accuracy: 0.7904
# Epoch 14/25
# 42/42 [==============================] - 9s 219ms/step - loss: 0.5506 - accuracy: 0.8478 - val_loss: 0.7983 - val_accuracy: 0.7665
# Epoch 15/25
# 42/42 [==============================] - 9s 217ms/step - loss: 0.5738 - accuracy: 0.8537 - val_loss: 0.8752 - val_accuracy: 0.7365
# Epoch 16/25
# 42/42 [==============================] - 9s 223ms/step - loss: 0.5722 - accuracy: 0.8507 - val_loss: 0.7606 - val_accuracy: 0.7964
# Epoch 17/25
# 42/42 [==============================] - 9s 216ms/step - loss: 0.5650 - accuracy: 0.8582 - val_loss: 0.7568 - val_accuracy: 0.7665
# Epoch 18/25
# 42/42 [==============================] - 9s 218ms/step - loss: 0.4837 - accuracy: 0.8955 - val_loss: 0.7834 - val_accuracy: 0.7665
# Epoch 19/25
# 42/42 [==============================] - 9s 220ms/step - loss: 0.5662 - accuracy: 0.8537 - val_loss: 0.8378 - val_accuracy: 0.7485
# Epoch 20/25
# 42/42 [==============================] - 9s 218ms/step - loss: 0.5328 - accuracy: 0.8761 - val_loss: 0.8588 - val_accuracy: 0.7605
# Epoch 21/25
# 42/42 [==============================] - 9s 220ms/step - loss: 0.5393 - accuracy: 0.8687 - val_loss: 0.8337 - val_accuracy: 0.8024
# Epoch 22/25
# 42/42 [==============================] - 9s 219ms/step - loss: 0.4769 - accuracy: 0.8910 - val_loss: 0.8315 - val_accuracy: 0.7725
# Epoch 23/25
# 42/42 [==============================] - 9s 217ms/step - loss: 0.4859 - accuracy: 0.8925 - val_loss: 0.6747 - val_accuracy: 0.8383
# Epoch 24/25
# 42/42 [==============================] - 9s 224ms/step - loss: 0.4587 - accuracy: 0.9015 - val_loss: 0.8980 - val_accuracy: 0.8024
# Epoch 25/25
# 42/42 [==============================] - 9s 216ms/step - loss: 0.4614 - accuracy: 0.9075 - val_loss: 0.9190 - val_accuracy: 0.7904

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_ds, verbose=1)
# Out:
# 5/5 [==============================] - 0s 38ms/step - loss: 1.2431 - accuracy: 0.6750

# %%
print('Test accuracy: ' +  str(test_acc) + " Loss: " + str(test_loss))
# Out:
# Test accuracy: 0.675000011920929 Loss: 1.243080496788025

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])
predictions = probability_model.predict(test_ds)

# %%
predictions[0]
# Out:
# array([3.9901715e-03, 1.5133858e-04, 1.5129111e-04, 9.9570721e-01],
#       dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 3

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(batch_size):
        ax = plt.subplot(7, 5, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[np.argmax(predictions[i])])
        plt.axis("off")

# %%
prediction_counter = 0
l = []
p = []
for images, labels in test_ds:
    for i in range(len(labels)):
        l.append(labels[i].numpy())
        p.append(np.argmax(predictions[prediction_counter]))
        prediction_counter += 1

# %%
cm = tf.math.confusion_matrix(l, p)
cm = cm / len(l)

# %%
# https://docs.python.org/3/library/itertools.html#module-itertools
# https://www.tensorflow.org/api_docs/python/tf/math/confusion_matrix
def plot_confusion_matrix(cm, class_names):
    """
    Returns a matplotlib figure containing the plotted confusion matrix.
    
    Args:
       cm (array, shape = [n, n]): a confusion matrix of integer classes
       class_names (array, shape = [n]): String names of the integer classes
    """
    
    figure = plt.figure(figsize=(8, 8))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion matrix")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)
    
    # Use white text if squares are dark; otherwise black.
    threshold = np.max(cm) / 2.
    
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        color = "white" if cm[i, j] > threshold else "black"
        plt.text(j, i, cm[i, j].numpy(), horizontalalignment="center", color=color)
        
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    #return figure

# %%
plot_confusion_matrix(cm, class_names)
